# %% [markdown]
# # Demo Anomaly Injection V2 — Google Colab

# %%
# !pip -q install pandas numpy pyyaml openpyxl matplotlib scikit-learn

# %%
from google.colab import files
uploaded=files.upload()
DATASET=next(iter(uploaded.keys()))
print(DATASET)

# %%
# !python inject_anomaly_v2.py --input '$DATASET' --config anomaly_config.yaml --output-dir sample_output --window-size 7

# %%
import pandas as pd, json
display(pd.read_excel('sample_output/Data_AMR_Anomaly_v2.xlsx').head())
display(pd.read_csv('sample_output/anomaly_report.csv').head())
print(json.load(open('sample_output/dataset_statistics.json')))
